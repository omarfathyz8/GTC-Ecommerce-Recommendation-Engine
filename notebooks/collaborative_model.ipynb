# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\nice\Desktop\projects\GTC recomomdation system\data\clean_model1_reviews.csv")

# %%
df=df.drop(columns=["Unnamed: 0"]).copy()

# %%
df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568423  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568424  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568425  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568426  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568427  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %% [markdown]
# # Feature engineering

# %%
df["helpfulness_ratio"] = df.apply(
    lambda x: x["HelpfulnessNumerator"]/x["HelpfulnessDenominator"]
    if x["HelpfulnessDenominator"] > 0 else 0, axis=1)
df["score_weight"]=df["helpfulness_ratio"]*df["Score"]
df["score_weight"].describe()
# Out:
# count    568428.000000
# mean          1.723252
# std           2.153121
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           4.000000
# max          15.000000
# Name: score_weight, dtype: float64

# %%
year=df["year"].max()
df["time_weight"]=1/(1+(year-df["year"]))
df["score_weight2"]=df["time_weight"]*df["Score"]
df["score_weight2"].describe()
# Out:
# count    568428.000000
# mean          2.440485
# std           1.579200
# min           0.076923
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max           5.000000
# Name: score_weight2, dtype: float64

# %%
df["fianl_score"]=df["helpfulness_ratio"]*df["time_weight"]*df["Score"]
df["final_score2"]=np.log1p(df["helpfulness_ratio"])*df["time_weight"]*df["Score"]
df["final_score3"] = np.sqrt(df["helpfulness_ratio"])*df["time_weight"]*df["Score"]

# %%
df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568423  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568424  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568425  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568426  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568427  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
df["Score"].describe()
# Out:
# count    568428.000000
# mean          4.183196
# std           1.310427
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: Score, dtype: float64

# %%
df.to_csv(r"C:\Users\nice\Desktop\projects\GTC recomomdation system\data\final_data_model_1.csv")

# %%
df.isna().sum()
# Out:
# Id                        0
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# year                      0
# month                     0
# day                       0
# dayofweek                 0
# helpfulness_ratio         0
# score_weight              0
# time_weight               0
# score_weight2             0
# fianl_score               0
# final_score2              0
# final_score3              0
# dtype: int64

# %% [markdown]
# # Modeling

# %%
from surprise import Dataset, Reader
data_cf=df[["UserId","ProductId","final_score2"]]
reader=Reader(rating_scale=(1,5))  
dataset=Dataset.load_from_df(data_cf,reader)

# %%
from surprise.model_selection import train_test_split
trainset,testset =train_test_split(dataset,test_size=0.2,random_state=42)

# %%
from surprise import SVD
from surprise import accuracy
model=SVD()
model.fit(trainset)
predictions=model.test(testset)
accuracy.rmse(predictions)
accuracy.mae(predictions)
# Out:
# RMSE: 0.9591
# MAE:  0.8412
# 0.8411689772985843

# %%
from surprise.model_selection import RandomizedSearchCV
param_dist = {
    'n_factors':[50, 100, 150, 200,250],
    'n_epochs':[20, 40, 60, 80],
    'lr_all':np.linspace(0.002, 0.02,5),
    'reg_all':np.linspace(0.02, 0.1,5)}
rs=RandomizedSearchCV(SVD, param_distributions=param_dist,measures=['rmse','mae'],cv=3,n_iter=10,random_state=42)
rs.fit(dataset)
print("Best RMSE score:", rs.best_score['rmse'])
print("Best hyperparameters:", rs.best_params['rmse'])
# Out:
# Best RMSE score: 0.941394666037419
# Best hyperparameters: {'n_factors': 50, 'n_epochs': 60, 'lr_all': 0.006500000000000001, 'reg_all': 0.04}

# %%
from surprise import SVD
from surprise import accuracy
model=SVD(n_factors=50,n_epochs=80,lr_all= 0.02,reg_all= 0.08)
model.fit(trainset)
predictions=model.test(testset)
accuracy.rmse(predictions)
accuracy.mae(predictions)
# Out:
# RMSE: 0.9332
# MAE:  0.8110
# 0.8110246918561007

# %%
save_dict={
    "model": model,
    "trainset": trainset,
    "reader": reader,
    "df_stats": {
        "min_val": df["final_score2"].min(),
        "max_val": df["final_score2"].max()
    }
} 
import joblib
joblib.dump(save_dict,r"C:\Users\nice\Desktop\projects\GTC recomomdation system\models\svd_full.pkl",compress=9)
# Out:
# ['C:\\Users\\nice\\Desktop\\projects\\GTC recomomdation system\\models\\svd_full.pkl']
